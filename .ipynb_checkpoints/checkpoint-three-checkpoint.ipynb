# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset: https://www.kaggle.com/datasets/andreuvallhernndez/myanimelist?select=manga.csv
#
# Import the necessary libraries and create your dataframe(s).

# %% [markdown]
# <font color=Red>**Data Cleaning Note:**</font> I've rearranged the structure of this notebook to maximize the cleaning of this data. I found it to be more effecient to remove unnecessary data/columns first and then handle missing data from the remaining columns.

# %%
#import needed libraires with aliases
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

anime_df = pd.read_csv("anime.csv")
manga_df = pd.read_csv("manga.csv")

# Want to see if the dataframe was properly imported and see what kind of data is stored in each column.
anime_df.info()
manga_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24165 entries, 0 to 24164
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          24165 non-null  int64
#  1   title             24165 non-null  object
#  2   type              24092 non-null  object
#  3   score             14272 non-null  float64
#  4   scored_by         24165 non-null  int64
#  5   status            24165 non-null  object
#  6   episodes          23397 non-null  float64
#  7   start_date        21391 non-null  object
#  8   end_date          19912 non-null  object
#  9   source            20404 non-null  object
#  10  members           24165 non-null  int64
#  11  favorites         24165 non-null  int64
#  12  episode_duration  23302 non-null  object
#  13  total_duration    23002 non-null  object
#  14  rating            23148 non-null  object
#  15  sfw               24165 non-null  bool
#  16  approved          24165 non-null  bool
#  17  created_at        24165 non-null  object
#  18  updated_at        24165 non-null  object
#  19  start_year        17749 non-null  float64
#  20  start_season      17749 non-null  object
#  21  real_start_date   21391 non-null  object
#  22  real_end_date     19912 non-null  object
#  23  broadcast_day     3065 non-null   object
#  24  broadcast_time    2928 non-null   object
#  25  genres            24165 non-null  object
#  26  themes            24165 non-null  object
#  27  demographics      24165 non-null  object
#  28  studios           24165 non-null  object
#  29  producers         24165 non-null  object
#  30  licensors         24165 non-null  object
#  31  synopsis          20848 non-null  object
#  32  background        2342 non-null   object
#  33  main_picture      21378 non-null  object
#  34  url               24165 non-null  object
#  35  trailer_url       4362 non-null   object
#  36  title_english     9084 non-null   object
#  37  title_japanese    23911 non-null  object
#  38  title_synonyms    24165 non-null  object
# dtypes: bool(2), float64(3), int64(4), object(30)
# memory usage: 6.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67273 entries, 0 to 67272
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manga_id           67273 non-null  int64
#  1   title              67273 non-null  object
#  2   type               67273 non-null  object
#  3   score              21910 non-null  float64
#  4   scored_by          67273 non-null  int64
#  5   status             67273 non-null  object
#  6   volumes            50494 non-null  float64
#  7   chapters           47095 non-null  float64
#  8   start_date         62949 non-null  object
#  9   end_date           51721 non-null  object
#  10  members            67273 non-null  int64
#  11  favorites          67273 non-null  int64
#  12  sfw                67273 non-null  bool
#  13  approved           67273 non-null  bool
#  14  created_at_before  67273 non-null  object
#  15  updated_at         58991 non-null  object
#  16  real_start_date    62949 non-null  object
#  17  real_end_date      51721 non-null  object
#  18  genres             67273 non-null  object
#  19  themes             67273 non-null  object
#  20  demographics       67273 non-null  object
#  21  authors            67273 non-null  object
#  22  serializations     67273 non-null  object
#  23  synopsis           45620 non-null  object
#  24  background         9339 non-null   object
#  25  main_picture       64832 non-null  object
#  26  url                67273 non-null  object
#  27  title_english      18427 non-null  object
#  28  title_japanese     64593 non-null  object
#  29  title_synonyms     67273 non-null  object
#  30  jikan              67273 non-null  bool
# dtypes: bool(3), float64(3), int64(4), object(21)
# memory usage: 14.6+ MB

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %% [markdown]
# <h1 style="background-color:Blue; color:White; text-align:center">Anime Unnecessary Data Evaluation</h1>

# %% [markdown]
# The business issue is focused on helping the staff members in a school district understand their students better through learning and exploring the key elements of anime. Not all of the columns in this data set are relevent for that purpose and the following 12 columns will be dropped:
# * created_at
# * updated_at
# * real_start_date
# * real_end_date
# * broadcast_day
# * broadcast_time
# * main_picture
# * url
# * trailer_url
# * title_english
# * title_japanese
# * title_synonyms
#
# The Approved column provideds true or false values based on if that record was approved by the currators of the database. The unappoved content has significant errors and missing values. For the purpose of the bussiness issue, records that are unaproved / false will be dropped to so that the data can effectively display the key feature of anime. False values reprsent 14% of the data equating to rough 3,000 rows.

# %%
anime_df.drop(['created_at','updated_at','real_start_date','real_end_date','broadcast_day','broadcast_time','main_picture','url','trailer_url','title_english','title_japanese','title_synonyms'],axis=1, inplace = True)

# %%
pd.set_option('display.max_columns', None) # This was used to display the columns in the dataframe
anime_df.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1509622
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 3      9253                         Steins;Gate     tv   9.08    1252286
# 4     28851                      Koe no Katachi  movie   8.95    1398608
#
#             status  episodes  start_date    end_date        source  members  \
# 0  finished_airing      64.0  2009-04-05  2010-07-04         manga  2932347
# 1  finished_airing     148.0  2011-10-02  2014-09-24         manga  2418883
# 2  finished_airing      10.0  2019-04-29  2019-07-01         manga  1881734
# 3  finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  2269121
# 4  finished_airing       1.0  2016-09-17  2016-09-17         manga  2001335
#
#    favorites episode_duration   total_duration rating   sfw  approved  \
# 0     204645  0 days 00:24:20  1 days 01:57:20      r  True      True
# 1     185178  0 days 00:23:37  2 days 10:15:16  pg_13  True      True
# 2      51931  0 days 00:23:55  0 days 03:59:10      r  True      True
# 3     173088  0 days 00:24:20  0 days 09:44:00  pg_13  True      True
# 4      77431  0 days 02:10:03  0 days 02:10:03  pg_13  True      True
#
#    start_year start_season                                       genres  \
# 0      2009.0       spring  ['Action', 'Adventure', 'Drama', 'Fantasy']
# 1      2011.0         fall           ['Action', 'Adventure', 'Fantasy']
# 2      2019.0       spring                          ['Action', 'Drama']
# 3      2011.0       spring              ['Drama', 'Sci-Fi', 'Suspense']
# 4      2016.0       summer                                    ['Drama']
#
#                              themes demographics              studios  \
# 0                      ['Military']  ['Shounen']            ['Bones']
# 1                                []  ['Shounen']         ['Madhouse']
# 2  ['Gore', 'Military', 'Survival']  ['Shounen']       ['Wit Studio']
# 3  ['Psychological', 'Time Travel']           []        ['White Fox']
# 4              ['Romantic Subtext']  ['Shounen']  ['Kyoto Animation']
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Movic', '...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background
# 0                                                NaN
# 1                                                NaN
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' re...
# 4  Winner of the Excellence Award on the 20th Jap...

# %%
anime_df.approved.value_counts()
# Out:
# True     20760
# False     3405
# Name: approved, dtype: int64

# %%
anime_df.drop(anime_df[anime_df['approved'] == False].index, inplace = True)

# %%
anime_df.approved.value_counts() #Verifying the False values are gone
# Out:
# True    20760
# Name: approved, dtype: int64

# %% [markdown]
# <h1 style="background-color:Purple; color:White; text-align:center">Manga Unnecessary Data Evaluation</h1>

# %%
unique_manga_counts = manga_df.nunique()
unique_manga_counts
# Out:
# manga_id             67273
# title                63987
# type                     7
# score                  403
# scored_by             4406
# status                   5
# volumes                 79
# chapters               432
# start_date            9292
# end_date              8508
# members               7058
# favorites             1083
# sfw                      2
# approved                 2
# created_at_before     4986
# updated_at           58830
# real_start_date       9697
# real_end_date         8875
# genres                1972
# themes                 944
# demographics            16
# authors              28981
# serializations        1163
# synopsis             44495
# background            9294
# main_picture         64832
# url                  67273
# title_english        17542
# title_japanese       62172
# title_synonyms       32054
# jikan                    2
# dtype: int64

# %% [markdown]
# Similar to the Anime Table, not all of the columns in this data set are relevent to the business issue and the following 11 columns will be dropped:
# * created_at_before
# * updated_at
# * real_start_date
# * real_end_date
# * background
# * main_picture
# * url
# * title_english
# * title_japanese
# * title_synonyms
# * jikan
#
#
# The Approved column provideds true or false values based on if that record was approved by the currators of the database. The unappoved content has significant errors and missing values. For the purpose of the bussiness issue, records that are unaproved / false will be dropped to so that the data can effectively display the key feature of anime. False values reprsent 11% of the data equating to rough 7,000 rows.

# %%
manga_df.drop(['created_at_before','updated_at','real_start_date','real_end_date','background','main_picture',
'url','title_english','title_japanese','title_synonyms','jikan'],axis=1, inplace = True)
manga_df.head()
# Out:
#    manga_id                                            title   type  score  \
# 0         2                                          Berserk  manga   9.45
# 1        13                                        One Piece  manga   9.20
# 2        25                              Fullmetal Alchemist  manga   9.05
# 3      1706  JoJo no Kimyou na Bouken Part 7: Steel Ball Run  manga   9.27
# 4      4632                                   Oyasumi Punpun  manga   9.03
#
#    scored_by                status  volumes  chapters  start_date    end_date  \
# 0     268737  currently_publishing      NaN       NaN  1989-08-25         NaN
# 1     305917  currently_publishing      NaN       NaN  1997-07-22         NaN
# 2     143879              finished     27.0     116.0  2001-07-12  2010-09-11
# 3     125482              finished     24.0      96.0  2004-01-19  2011-04-19
# 4     141146              finished     13.0     147.0  2007-03-15  2013-11-02
#
#    members  favorites   sfw  approved  \
# 0   551266     103820  True      True
# 1   501291      99526  True      True
# 2   264571      28519  True      True
# 3   209123      35456  True      True
# 4   354176      43168  True      True
#
#                                               genres  \
# 0  ['Action', 'Adventure', 'Award Winning', 'Dram...
# 1                 ['Action', 'Adventure', 'Fantasy']
# 2  ['Action', 'Adventure', 'Award Winning', 'Dram...
# 3  ['Action', 'Adventure', 'Horror', 'Mystery', '...
# 4                         ['Drama', 'Slice of Life']
#
#                                               themes           demographics  \
# 0  ['Gore', 'Military', 'Mythology', 'Psychologic...             ['Seinen']
# 1                                                 []            ['Shounen']
# 2                                       ['Military']            ['Shounen']
# 3                                     ['Historical']  ['Seinen', 'Shounen']
# 4                                  ['Psychological']             ['Seinen']
#
#                                              authors  \
# 0  [{'id': 1868, 'first_name': 'Kentarou', 'last_...
# 1  [{'id': 1881, 'first_name': 'Eiichiro', 'last_...
# 2  [{'id': 1874, 'first_name': 'Hiromu', 'last_na...
# 3  [{'id': 2619, 'first_name': 'Hirohiko', 'last_...
# 4  [{'id': 2836, 'first_name': 'Inio', 'last_name...
#
#               serializations  \
# 0           ['Young Animal']
# 1  ['Shounen Jump (Weekly)']
# 2         ['Shounen Gangan']
# 3             ['Ultra Jump']
# 4      ['Big Comic Spirits']
#
#                                             synopsis
# 0  Guts, a former mercenary now known as the "Bla...
# 1  Gol D. Roger, a man referred to as the "Pirate...
# 2  Alchemists are knowledgeable and naturally tal...
# 3  In the American Old West, the world's greatest...
# 4  Punpun Onodera is a normal 11-year-old boy liv...

# %%
manga_df.approved.value_counts()
# Out:
# True     59969
# False     7304
# Name: approved, dtype: int64

# %%
manga_df.drop(manga_df[manga_df['approved'] == False].index, inplace = True)

# %%
manga_df.approved.value_counts() #Verifying the False values are gone
# Out:
# True    59969
# Name: approved, dtype: int64

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %% [markdown]
# <h1 style="background-color:Blue; color:White; text-align:center">Anime Missing Data Evaluation</h1>

# %%
number_of_columns = anime_df.shape # I'm viewing the shape to verify the heat map below
number_of_columns
# Out:
# (20760, 27)

# %%
# Plot a heatmap of any missing data for Anime Dataset

cols = anime_df.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(anime_df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Notes About The Data:
#
# There are a lot of nulls in the 'score' column due to the anime never being scored by viewers. The 'scored_by' column is not null has the value of 0 because no one score it. Since the score column is numerical I'll be changing anyy null value to be 0.

# %%
anime_df1 = anime_df[anime_df.isna().any(axis=1)]
anime_df1
# Out:
#        anime_id                                           title   type  score  \
# 0          5114                Fullmetal Alchemist: Brotherhood     tv   9.13
# 1         11061                          Hunter x Hunter (2011)     tv   9.04
# 7         40028            Shingeki no Kyojin: The Final Season     tv   8.83
# 14           21                                       One Piece     tv   8.66
# 18        37510                               Mob Psycho 100 II     tv   8.81
# ...         ...                                             ...    ...    ...
# 20755     47237                                  Wo Yao Hui Jia     tv    NaN
# 20756     52463                                   Madtoy Chatty     tv    NaN
# 20757     52471                             Lyeonglihan Neoguli     tv    NaN
# 20758     52452  Sore Ike! Anpanman: Dororin to Bakeru Carnival  movie    NaN
# 20759     51289                                        Zhe Tian    ona    NaN
#
#        scored_by            status  episodes  start_date    end_date  \
# 0        1871705   finished_airing      64.0  2009-04-05  2010-07-04
# 1        1509622   finished_airing     148.0  2011-10-02  2014-09-24
# 7        1080165   finished_airing      16.0  2020-12-07  2021-03-29
# 14       1095305  currently_airing       NaN  1999-10-20         NaN
# 18        794061   finished_airing      13.0  2019-01-07  2019-04-01
# ...          ...               ...       ...         ...         ...
# 20755          1   finished_airing      26.0  2017-03-13  2017-01-01
# 20756          1  currently_airing       NaN  2022-04-20         NaN
# 20757          1   finished_airing      63.0  1987-01-01  2009-01-01
# 20758          0   finished_airing       1.0  2022-06-24  2022-06-24
# 20759          0     not_yet_aired       NaN  2023-01-01         NaN
#
#           source  members  favorites episode_duration   total_duration rating  \
# 0          manga  2932347     204645  0 days 00:24:20  1 days 01:57:20      r
# 1          manga  2418883     185178  0 days 00:23:37  2 days 10:15:16  pg_13
# 7          manga  1629273      50125  0 days 00:23:55  0 days 06:22:40      r
# 14         manga  1922827     171418  0 days 00:24:00              NaN  pg_13
# 18     web_manga  1261348      29183  0 days 00:24:10  0 days 05:14:10  pg_13
# ...          ...      ...        ...              ...              ...    ...
# 20755        NaN       14          0  0 days 00:15:20  0 days 06:38:40     pg
# 20756   original       14          0  0 days 00:01:00              NaN      g
# 20757   original       12          0  0 days 00:13:00  0 days 13:39:00     pg
# 20758        NaN       10          0  0 days 01:05:00  0 days 01:05:00     pg
# 20759  web_novel        6          0              NaN              NaN  pg_13
#
#         sfw  approved  start_year start_season  \
# 0      True      True      2009.0       spring
# 1      True      True      2011.0         fall
# 7      True      True      2021.0       winter
# 14     True      True      1999.0         fall
# 18     True      True      2019.0       winter
# ...     ...       ...         ...          ...
# 20755  True      True         NaN          NaN
# 20756  True      True      2022.0       spring
# 20757  True      True         NaN          NaN
# 20758  True      True      2022.0       spring
# 20759  True      True         NaN          NaN
#
#                                             genres  \
# 0      ['Action', 'Adventure', 'Drama', 'Fantasy']
# 1               ['Action', 'Adventure', 'Fantasy']
# 7                              ['Action', 'Drama']
# 14              ['Action', 'Adventure', 'Fantasy']
# 18            ['Action', 'Comedy', 'Supernatural']
# ...                                            ...
# 20755                     ['Adventure', 'Fantasy']
# 20756                                   ['Comedy']
# 20757                                           []
# 20758                        ['Comedy', 'Fantasy']
# 20759            ['Action', 'Adventure', 'Sci-Fi']
#
#                                  themes demographics               studios  \
# 0                          ['Military']  ['Shounen']             ['Bones']
# 1                                    []  ['Shounen']          ['Madhouse']
# 7      ['Gore', 'Military', 'Survival']  ['Shounen']             ['MAPPA']
# 14                                   []  ['Shounen']    ['Toei Animation']
# 18                      ['Super Power']           []             ['Bones']
# ...                                 ...          ...                   ...
# 20755                                []     ['Kids']                    []
# 20756                                []           []  ['Kachidoki Studio']
# 20757                                []     ['Kids']                    []
# 20758                                []     ['Kids']                    []
# 20759                                []           []                    []
#
#                                                producers  \
# 0      ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1       ['VAP', 'Nippon Television Network', 'Shueisha']
# 7      ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 14                        ['Fuji TV', 'TAP', 'Shueisha']
# 18     ['Warner Bros. Japan', 'KlockWorx', 'BS Fuji',...
# ...                                                  ...
# 20755                                                 []
# 20756                                                 []
# 20757                                                 []
# 20758                                                 []
# 20759                                                 []
#
#                                    licensors  \
# 0       ['Funimation', 'Aniplex of America']
# 1                              ['VIZ Media']
# 7                             ['Funimation']
# 14     ['Funimation', '4Kids Entertainment']
# 18                            ['Funimation']
# ...                                      ...
# 20755                                     []
# 20756                                     []
# 20757                                     []
# 20758                                     []
# 20759                                     []
#
#                                                 synopsis  \
# 0      After a horrific alchemy experiment goes wrong...
# 1      Hunters devote themselves to accomplishing haz...
# 7      Gabi Braun and Falco Grice have been training ...
# 14     Gol D. Roger was known as the "Pirate King," t...
# 18     Shigeo "Mob" Kageyama is now maturing and unde...
# ...                                                  ...
# 20755                                                NaN
# 20756                                                NaN
# 20757  Clever Raccoon Dog is a North Korean animated ...
# 20758                                                NaN
# 20759                                                NaN
#
#                                               background
# 0                                                    NaN
# 1                                                    NaN
# 7                                                    NaN
# 14     Several anime-original arcs have been adapted ...
# 18                                                   NaN
# ...                                                  ...
# 20755                                                NaN
# 20756                                                NaN
# 20757                                                NaN
# 20758                                                NaN
# 20759                                                NaN
#
# [19205 rows x 27 columns]

# %%
anime_df['score'] = anime_df['score'].fillna('0')

# %%
anime_df['source'] = anime_df['source'].fillna('unknown')

# %%
anime_df['background'] = anime_df['background'].fillna('Not Available')

# %%
anime_df['synopsis'] = anime_df['synopsis'].fillna('Not Available')

# %%
anime_df['start_season'] = anime_df['start_season'].fillna('Not Available')

# %%
anime_df['start_year'] = anime_df['start_year'].fillna('Not Available')

# %%
# Plot a heatmap to check that the above columns have no more null values

cols = anime_df.columns 
colours = ['#0000CD', '#FFC125'] # specify the colours - orange is missing. blue is not missing.
sns.heatmap(anime_df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
for col in anime_df.columns:
    pct_missing = np.mean(anime_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# anime_id - 0%
# title - 0%
# type - 0%
# score - 0%
# scored_by - 0%
# status - 0%
# episodes - 3%
# start_date - 2%
# end_date - 6%
# source - 0%
# members - 0%
# favorites - 0%
# episode_duration - 3%
# total_duration - 4%
# rating - 3%
# sfw - 0%
# approved - 0%
# start_year - 0%
# start_season - 0%
# genres - 0%
# themes - 0%
# demographics - 0%
# studios - 0%
# producers - 0%
# licensors - 0%
# synopsis - 0%
# background - 0%

# %%
anime_df1 = anime_df[anime_df.isna().any(axis=1)]
anime_df1
# Out:
#        anime_id                                              title type score  \
# 14           21                                          One Piece   tv  8.66
# 305         235                                    Detective Conan   tv  8.16
# 678       47194                                  Summertime Render   tv  8.43
# 927       51096  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...   tv  8.12
# 1027      48895                                        Overlord IV   tv  8.32
# ...         ...                                                ...  ...   ...
# 20749     47217                                   Jibian Ying Meng  ona     0
# 20750     47234                                   Lie Che Shou Hun   tv     0
# 20752     47239                                       Qi Ji Leyuan   tv     0
# 20756     52463                                      Madtoy Chatty   tv     0
# 20759     51289                                           Zhe Tian  ona     0
#
#        scored_by            status  episodes  start_date end_date  \
# 14       1095305  currently_airing       NaN  1999-10-20      NaN
# 305       145740  currently_airing       NaN  1996-01-08      NaN
# 678        38820  currently_airing      25.0  2022-04-15      NaN
# 927        30373  currently_airing      13.0  2022-07-04      NaN
# 1027       22801  currently_airing       NaN  2022-07-05      NaN
# ...          ...               ...       ...         ...      ...
# 20749          1   finished_airing      40.0  2015-10-09      NaN
# 20750          2   finished_airing      46.0  2016-03-01      NaN
# 20752          2   finished_airing      52.0  2016-01-01      NaN
# 20756          1  currently_airing       NaN  2022-04-20      NaN
# 20759          0     not_yet_aired       NaN  2023-01-01      NaN
#
#             source  members  favorites episode_duration   total_duration  \
# 14           manga  1922827     171418  0 days 00:24:00              NaN
# 305          manga   312484      12783  0 days 00:25:00              NaN
# 678          manga   233002       2148  0 days 00:23:42  0 days 09:52:30
# 927    light_novel   226779       2833  0 days 00:23:40  0 days 05:07:40
# 1027   light_novel   271615       4069  0 days 00:23:40              NaN
# ...            ...      ...        ...              ...              ...
# 20749     original       15          0  0 days 00:12:20  0 days 08:13:20
# 20750     original       15          0  0 days 00:22:20  0 days 17:07:20
# 20752     original       15          0  0 days 00:05:20  0 days 04:37:20
# 20756     original       14          0  0 days 00:01:00              NaN
# 20759    web_novel        6          0              NaN              NaN
#
#       rating   sfw  approved     start_year   start_season  \
# 14     pg_13  True      True         1999.0           fall
# 305    pg_13  True      True         1996.0         winter
# 678        r  True      True         2022.0         spring
# 927    pg_13  True      True         2022.0         summer
# 1027       r  True      True         2022.0         summer
# ...      ...   ...       ...            ...            ...
# 20749     pg  True      True         2015.0           fall
# 20750     pg  True      True  Not Available  Not Available
# 20752     pg  True      True  Not Available  Not Available
# 20756      g  True      True         2022.0         spring
# 20759  pg_13  True      True  Not Available  Not Available
#
#                                         genres                       themes  \
# 14          ['Action', 'Adventure', 'Fantasy']                           []
# 305         ['Adventure', 'Comedy', 'Mystery']                ['Detective']
# 678    ['Mystery', 'Supernatural', 'Suspense']                           []
# 927                      ['Drama', 'Suspense']  ['Psychological', 'School']
# 1027     ['Action', 'Fantasy', 'Supernatural']     ['Isekai', 'Video Game']
# ...                                        ...                          ...
# 20749                     ['Action', 'Sci-Fi']                    ['Mecha']
# 20750        ['Action', 'Adventure', 'Sci-Fi']                           []
# 20752                              ['Fantasy']                           []
# 20756                               ['Comedy']                           []
# 20759        ['Action', 'Adventure', 'Sci-Fi']                           []
#
#       demographics                studios  \
# 14     ['Shounen']     ['Toei Animation']
# 305    ['Shounen']  ['TMS Entertainment']
# 678    ['Shounen']                ['OLM']
# 927             []             ['Lerche']
# 1027            []           ['Madhouse']
# ...            ...                    ...
# 20749           []                     []
# 20750     ['Kids']                     []
# 20752     ['Kids']                     []
# 20756           []   ['Kachidoki Studio']
# 20759           []                     []
#
#                                                producers  \
# 14                        ['Fuji TV', 'TAP', 'Shueisha']
# 305    ['Yomiuri Telecasting', 'TMS-Kyokuchi', 'Shoga...
# 678    ['Movic', 'MAGES.', 'Tokyo MX', 'Shueisha', "T...
# 927    ['Studio Hibari', 'Movic', 'AT-X', 'Sammy', 'C...
# 1027   ['AT-X', 'Hakuhodo DY Music & Pictures', 'NTT ...
# ...                                                  ...
# 20749                                                 []
# 20750                                                 []
# 20752                                                 []
# 20756                                                 []
# 20759                                                 []
#
#                                    licensors  \
# 14     ['Funimation', '4Kids Entertainment']
# 305            ['Funimation', 'Crunchyroll']
# 678                                       []
# 927                                       []
# 1027                                      []
# ...                                      ...
# 20749                                     []
# 20750                                     []
# 20752                                     []
# 20756                                     []
# 20759                                     []
#
#                                                 synopsis  \
# 14     Gol D. Roger was known as the "Pirate King," t...
# 305    Shinichi Kudou, a high school student of astou...
# 678    Since the death of his parents, Shinpei Ajiro ...
# 927    Tokyo Metropolitan Advanced Nurturing High Sch...
# 1027                          Fourth season of Overlord.
# ...                                                  ...
# 20749                                      Not Available
# 20750                                      Not Available
# 20752                                      Not Available
# 20756                                      Not Available
# 20759                                      Not Available
#
#                                               background
# 14     Several anime-original arcs have been adapted ...
# 305    In 2003, FUNimation licensed the first 104 epi...
# 678                                        Not Available
# 927                                        Not Available
# 1027                                       Not Available
# ...                                                  ...
# 20749                                      Not Available
# 20750                                      Not Available
# 20752                                      Not Available
# 20756                                      Not Available
# 20759                                      Not Available
#
# [1881 rows x 27 columns]

# %% [markdown]
# <h1 style="background-color:Purple; color:White; text-align:center">Manga Missing Data Evaluation</h1>

# %%
number_of_columns = manga_df.shape # I'm viewing the shape to verify the heat map below
number_of_columns
# Out:
# (59969, 20)

# %%
# Plot a heatmap of any missing data for Manga Dataset

cols = manga_df.columns 
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(manga_df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
for col in manga_df.columns:
    pct_missing = np.mean(manga_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# manga_id - 0%
# title - 0%
# type - 0%
# score - 0%
# scored_by - 0%
# status - 0%
# volumes - 0%
# chapters - 0%
# start_date - 0%
# end_date - 0%
# members - 0%
# favorites - 0%
# sfw - 0%
# approved - 0%
# genres - 0%
# themes - 0%
# demographics - 0%
# authors - 0%
# serializations - 0%
# synopsis - 0%

# %%
manga_df['score'] = manga_df['score'].fillna('0')

# %%
manga_df['synopsis'] = manga_df['synopsis'].fillna('Not Available')

# %%
manga_df['chapters'] = manga_df['chapters'].fillna('Unknown')

# %%
manga_df['volumes'] = manga_df['volumes'].fillna('Unknown')

# %%
# manga_df['start_date'] = manga_df['start_date'].fillna('Unknown')

# %%
# manga_df['end_date'] = manga_df['end_date'].fillna('Unknown')

# %%
# Plot a heatmap to check that the above columns have no more null values

cols = manga_df.columns 
colours = ['#0000CD', '#FFC125'] # specify the colours - orange is missing. blue is not missing.
sns.heatmap(manga_df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %% [markdown]
# <h1 style="background-color:Blue; color:White; text-align:center">Anime Irregular Data Evaluation</h1>

# %%
anime_df['type'].value_counts()
# Out:
# tv         6044
# ova        3963
# movie      3783
# ona        2646
# special    2375
# music      1895
# Name: type, dtype: int64

# %%
anime_df['status'].value_counts()
# Out:
# finished_airing     20023
# not_yet_aired         415
# currently_airing      322
# Name: status, dtype: int64

# %%
anime_df['source'].value_counts()
# Out:
# original        6950
# manga           4320
# unknown         3501
# visual_novel    1090
# game            1039
# light_novel      878
# other            827
# novel            633
# music            348
# web_manga        333
# 4_koma_manga     300
# picture_book     178
# book             150
# mixed_media       96
# card_game         65
# web_novel         39
# radio             13
# Name: source, dtype: int64

# %%
anime_df['rating'].value_counts()
# Through checking the ratings I discovered that "rx" is the rating for Hentai / Pornography. 
# Since this is for a school based presentation I'm going to drop all records with this rating to avoid pornographic material possibly enter a school setting due to the research.
# Out:
# pg_13    7414
# g        6636
# pg       2413
# rx       1432
# r        1310
# r+       1010
# Name: rating, dtype: int64

# %%
anime_df.drop(anime_df[anime_df['rating'] == 'rx'].index, inplace = True)

# %%
anime_df['rating'].value_counts()
# Out:
# pg_13    7414
# g        6636
# pg       2413
# r        1310
# r+       1010
# Name: rating, dtype: int64

# %%
anime_df2 = anime_df.melt(var_name='columns', value_name='index')
anime_df2
# Out:
#            columns          index
# 0         anime_id           5114
# 1         anime_id          11061
# 2         anime_id          38524
# 3         anime_id           9253
# 4         anime_id          28851
# ...            ...            ...
# 560515  background  Not Available
# 560516  background  Not Available
# 560517  background  Not Available
# 560518  background  Not Available
# 560519  background  Not Available
#
# [560520 rows x 2 columns]

# %%
pd.crosstab(index=anime_df2['index'], columns=anime_df2['columns'])
# Out:
# columns                                             anime_id  approved  \
# index
# 0                                                          0         0
# 1                                                          1     20760
# 1.85                                                       0         0
# 1.99                                                       0         0
# 2                                                          0         0
# ...                                                      ...       ...
# “Kotonoha Breakdown” is a song based on the mot...         0         0
# ”Wereman" Shushu's life is turned upside down w...         0         0
# ◯                                                          0         0
# 　                                                          0         0
# ーThe day the city had moved, our future began t...         0         0
#
# columns                                             background  demographics  \
# index
# 0                                                            0             0
# 1                                                            0             0
# 1.85                                                         0             0
# 1.99                                                         0             0
# 2                                                            0             0
# ...                                                        ...           ...
# “Kotonoha Breakdown” is a song based on the mot...           0             0
# ”Wereman" Shushu's life is turned upside down w...           0             0
# ◯                                                            0             0
# 　                                                            2             0
# ーThe day the city had moved, our future began t...           0             0
#
# columns                                             end_date  \
# index
# 0                                                          0
# 1                                                          0
# 1.85                                                       0
# 1.99                                                       0
# 2                                                          0
# ...                                                      ...
# “Kotonoha Breakdown” is a song based on the mot...         0
# ”Wereman" Shushu's life is turned upside down w...         0
# ◯                                                          0
# 　                                                          0
# ーThe day the city had moved, our future began t...         0
#
# columns                                             episode_duration  \
# index
# 0                                                                  0
# 1                                                                  0
# 1.85                                                               0
# 1.99                                                               0
# 2                                                                  0
# ...                                                              ...
# “Kotonoha Breakdown” is a song based on the mot...                 0
# ”Wereman" Shushu's life is turned upside down w...                 0
# ◯                                                                  0
# 　                                                                  0
# ーThe day the city had moved, our future began t...                 0
#
# columns                                             episodes  favorites  \
# index
# 0                                                          0       7587
# 1                                                       9783       2130
# 1.85                                                       0          0
# 1.99                                                       0          0
# 2                                                       1460       1123
# ...                                                      ...        ...
# “Kotonoha Breakdown” is a song based on the mot...         0          0
# ”Wereman" Shushu's life is turned upside down w...         0          0
# ◯                                                          0          0
# 　                                                          0          0
# ーThe day the city had moved, our future began t...         0          0
#
# columns                                             genres  licensors  \
# index
# 0                                                        0          0
# 1                                                        0          0
# 1.85                                                     0          0
# 1.99                                                     0          0
# 2                                                        0          0
# ...                                                    ...        ...
# “Kotonoha Breakdown” is a song based on the mot...       0          0
# ”Wereman" Shushu's life is turned upside down w...       0          0
# ◯                                                        0          0
# 　                                                        0          0
# ーThe day the city had moved, our future began t...       0          0
#
# columns                                             members  producers  \
# index
# 0                                                         0          0
# 1                                                         0          0
# 1.85                                                      0          0
# 1.99                                                      0          0
# 2                                                         0          0
# ...                                                     ...        ...
# “Kotonoha Breakdown” is a song based on the mot...        0          0
# ”Wereman" Shushu's life is turned upside down w...        0          0
# ◯                                                         0          0
# 　                                                         0          0
# ーThe day the city had moved, our future began t...        0          0
#
# columns                                             rating  score  scored_by  \
# index
# 0                                                        0      0        365
# 1                                                        0      0        201
# 1.85                                                     0      1          0
# 1.99                                                     0      1          0
# 2                                                        0      0        350
# ...                                                    ...    ...        ...
# “Kotonoha Breakdown” is a song based on the mot...       0      0          0
# ”Wereman" Shushu's life is turned upside down w...       0      0          0
# ◯                                                        0      0          0
# 　                                                        0      0          0
# ーThe day the city had moved, our future began t...       0      0          0
#
# columns                                               sfw  source  start_date  \
# index
# 0                                                    1475       0           0
# 1                                                   19285       0           0
# 1.85                                                    0       0           0
# 1.99                                                    0       0           0
# 2                                                       0       0           0
# ...                                                   ...     ...         ...
# “Kotonoha Breakdown” is a song based on the mot...      0       0           0
# ”Wereman" Shushu's life is turned upside down w...      0       0           0
# ◯                                                       0       0           0
# 　                                                       0       0           0
# ーThe day the city had moved, our future began t...      0       0           0
#
# columns                                             start_season  start_year  \
# index
# 0                                                              0           0
# 1                                                              0           0
# 1.85                                                           0           0
# 1.99                                                           0           0
# 2                                                              0           0
# ...                                                          ...         ...
# “Kotonoha Breakdown” is a song based on the mot...             0           0
# ”Wereman" Shushu's life is turned upside down w...             0           0
# ◯                                                              0           0
# 　                                                              0           0
# ーThe day the city had moved, our future began t...             0           0
#
# columns                                             status  studios  synopsis  \
# index
# 0                                                        0        0         0
# 1                                                        0        0         0
# 1.85                                                     0        0         0
# 1.99                                                     0        0         0
# 2                                                        0        0         0
# ...                                                    ...      ...       ...
# “Kotonoha Breakdown” is a song based on the mot...       0        0         1
# ”Wereman" Shushu's life is turned upside down w...       0        0         1
# ◯                                                        0        0         0
# 　                                                        0        0         0
# ーThe day the city had moved, our future began t...       0        0         1
#
# columns                                             themes  title  \
# index
# 0                                                        0      0
# 1                                                        0      0
# 1.85                                                     0      0
# 1.99                                                     0      0
# 2                                                        0      0
# ...                                                    ...    ...
# “Kotonoha Breakdown” is a song based on the mot...       0      0
# ”Wereman" Shushu's life is turned upside down w...       0      0
# ◯                                                        0      1
# 　                                                        0      0
# ーThe day the city had moved, our future began t...       0      0
#
# columns                                             total_duration  type
# index
# 0                                                                0     0
# 1                                                                0     0
# 1.85                                                             0     0
# 1.99                                                             0     0
# 2                                                                0     0
# ...                                                            ...   ...
# “Kotonoha Breakdown” is a song based on the mot...               0     0
# ”Wereman" Shushu's life is turned upside down w...               0     0
# ◯                                                                0     0
# 　                                                                0     0
# ーThe day the city had moved, our future began t...               0     0
#
# [93640 rows x 27 columns]

# %% [markdown]
# <h1 style="background-color:Purple; color:White; text-align:center">Manga Irregular Data Evaluation</h1>

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %% [markdown]
# <h1 style="background-color:Blue; color:White; text-align:center">Anime Inconsistent Data Evaluation</h1>

# %% [markdown]
# <h1 style="background-color:Purple; color:White; text-align:center">Manga Inconsistent Data Evaluation</h1>

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# 2. Did the process of cleaning your data give you new insights into your dataset?
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
